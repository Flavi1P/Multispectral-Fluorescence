# %% [markdown]
# # Prediction of the four different cluster
# <br/>
# We will try in this notebook to predict the four clusters in the hplc dataset from the 3x1m signal.

# %%
import pandas as pd

hplc_fluo = pd.read_csv("/home/flavien/Documents/these/mf/Boussole/Output/Data/Compiled/hplc_mf_clusterised.csv")
hplc_fluo.head()
#hplc_fluo = hplc_fluo[hplc_fluo["cluster"] != "group_1" ]
# Out:
#          date  bouss  depth    fluo_440    fluo_470   fluo_532  f440_f470  \
# 0  2020-12-09    225     80  105.760870  117.934783  97.217391   0.896774
# 1  2020-12-09    225     70   68.406780   80.491525  53.932203   0.849863
# 2  2020-12-09    225     60   81.857143   96.714286  58.190476   0.846381
# 3  2020-12-09    225     50   85.333333   98.375000  56.695652   0.867429
# 4  2020-12-09    225     40   92.979167  101.583333  57.127660   0.915299
#
#    f532_f470       bb700       cdom  ...    chlb  t_chlb  dv_chla    chla  \
# 0   0.824332  105.857143  56.902439  ...  0.0111  0.1246   0.0621  0.1247
# 1   0.670036  111.076923  57.607843  ...  0.0214  0.1050   0.0587  0.1629
# 2   0.601674  134.333333  61.476190  ...  0.0333  0.0472   0.0458  0.3454
# 3   0.576322  136.190476  57.857143  ...  0.0332  0.0452   0.0458  0.3512
# 4   0.562372  138.425532  58.744681  ...  0.0317  0.0437   0.0457  0.3516
#
#    t_chla  sumpig       CA1       CA2       CA3  group
# 0  0.1867  0.4915 -6.411167 -3.982536  4.927617      1
# 1  0.2216  0.5282 -4.740563 -2.604692  3.071990      1
# 2  0.3912  0.8056 -1.065213 -0.234678 -0.758305      2
# 3  0.3970  0.8203 -0.999813 -0.153111 -0.821612      2
# 4  0.3973  0.8166 -1.009486 -0.129671 -0.799814      2
#
# [5 rows x 35 columns]

# %%
target_name = "cluster"
target = hplc_fluo[target_name]
target.value_counts()
# Out:
# 3    40
# 2    32
# 4    30
# Name: group, dtype: int64

# %%
data = hplc_fluo[["fluo_440", "fluo_470", "fluo_532", "bb700"]]
data.describe()
# Out:
#          fluo_440    fluo_470    fluo_532       bb700
# count  102.000000  102.000000  102.000000  101.000000
# mean   118.047880  138.305438   65.866765  152.585745
# std     77.540904  103.067901   25.626514   40.642761
# min     50.819277   50.000000   50.888889   88.000000
# 25%     68.161765   71.484559   54.969531  126.000000
# 50%     90.608696   99.925926   58.978736  144.245614
# 75%    124.892857  145.513095   69.885784  172.562500
# max    394.405594  522.418440  278.220286  261.378378

# %% [markdown]
# Divide the dataset into learning and training test

# %%
from sklearn.model_selection import train_test_split

data_train, data_test, target_train, target_test = train_test_split(
    data, target, random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

model = Pipeline(steps=[
    ("preprocessor", StandardScaler()),
    ("classifier", KNeighborsClassifier(n_neighbors=5)),
])

# %%
from sklearn.model_selection import cross_validate

cv_results = cross_validate(model, data, target, cv = 5)
scores = cv_results["test_score"]
# Out:
# /home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/neighbors/_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "/home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/neighbors/_base.py", line 364, in _fit
#     multi_output=True)
#   File "/home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/utils/validation.py", line 878, in check_X_y
#     estimator=estimator)
#   File "/home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/utils/validation.py", line 721, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "/home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/utils/validation.py", line 106, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   FitFailedWarning)
# /home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:700: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/metrics/_scorer.py", line 397, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "/home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/utils/metaestimators.py", line 120, in <lambda>
#     out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)
#   File "/home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/pipeline.py", line 622, in score
#     return self.steps[-1][-1].score(Xt, y, **score_params)
#   File "/home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/base.py", line 500, in score
#     return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#   File "/home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/neighbors/_classification.py", line 195, in predict
#     X = check_array(X, accept_sparse='csr')
#   File "/home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/utils/validation.py", line 721, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "/home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/utils/validation.py", line 106, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   UserWarning,
# /home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/neighbors/_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "/home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/neighbors/_base.py", line 364, in _fit
#     multi_output=True)
#   File "/home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/utils/validation.py", line 878, in check_X_y
#     estimator=estimator)
#   File "/home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/utils/validation.py", line 721, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "/home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/utils/validation.py", line 106, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   FitFailedWarning)
# /home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/neighbors/_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "/home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/neighbors/_base.py", line 364, in _fit
#     multi_output=True)
#   File "/home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/utils/validation.py", line 878, in check_X_y
#     estimator=estimator)
#   File "/home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/utils/validation.py", line 721, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "/home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/utils/validation.py", line 106, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   FitFailedWarning)
# /home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/neighbors/_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "/home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/neighbors/_base.py", line 364, in _fit
#     multi_output=True)
#   File "/home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/utils/validation.py", line 878, in check_X_y
#     estimator=estimator)
#   File "/home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/utils/validation.py", line 721, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "/home/flavien/Documents/these/mf/mfenv/lib/python3.6/site-packages/sklearn/utils/validation.py", line 106, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   FitFailedWarning)
